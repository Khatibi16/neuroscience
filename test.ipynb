# %%
import microns_datacleaner as mic

cleaner = mic.MicronsDataCleaner(datadir = "../microns.h5", version=1300) 
cleaner.download_nucleus_data()
units, segments = cleaner.process_nucleus_data()
# Out:
# Downloading nucleus tables...: 100%|██████████| 6/6 [00:19<00:00,  3.28s/it]
# Transform positions: 100%|██████████| 94014/94014 [00:01<00:00, 67818.20it/s]
